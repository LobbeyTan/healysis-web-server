# %%
import pandas as pd
import numpy as np
import nltk
import re

# %%
df = pd.read_csv('sample_data/hospital-comments-report.csv', 
                 encoding='utf-8"',engine = 'python', encoding_errors='ignore')

# %%
df.head(3)
# Out:
#                                       Comment Title  Liked Disliked Sentiment
# 0  All the staff were exceptionally friendly and ...   NaN      NaN  Positive
# 1  Very professional but with a friendly approach...   NaN      NaN  Positive
# 2  Friendly Staff at all times, they put me at ea...   NaN      NaN  Positive

# %%
len(df)
# Out:
# 13771

# %%
df.isnull().sum()
# Out:
# Comment Title      357
# Liked             1549
# Disliked          3174
# Sentiment          346
# dtype: int64

# %%
df = df.drop('Liked', axis = 1)

# %%
df = df.drop('Disliked', axis = 1)

# %%
df.head()
# Out:
#                                       Comment Title  Sentiment
# 0  All the staff were exceptionally friendly and ...  Positive
# 1  Very professional but with a friendly approach...  Positive
# 2  Friendly Staff at all times, they put me at ea...  Positive
# 3  The care and consideration I received from the...  Positive
# 4  Everyone from the reception staff,pre-op nurse...  Positive

# %%
df.columns = ['comment', 'sentiment']

# %%
df.head(50)
# Out:
#                                               comment sentiment
# 0   All the staff were exceptionally friendly and ...  Positive
# 1   Very professional but with a friendly approach...  Positive
# 2   Friendly Staff at all times, they put me at ea...  Positive
# 3   The care and consideration I received from the...  Positive
# 4   Everyone from the reception staff,pre-op nurse...  Positive
# 5   Going into hospital is a daunting experience b...  Positive
# 6   friendly staff, efficient sevice, very relaxed...  Positive
# 7   The beautiful surroundings and the hospital it...  Positive
# 8   I enjoyed my stay,the staff were wonderful,the...  Positive
# 9   I attended the treatment centre for surgery an...  Positive
# 10  I liked the fact the every one there was frien...  Positive
# 11  Having never had to stay in hospital before i ...  Positive
# 12  A wonderfull hospital ! The facilities were ex...  Positive
# 13  after filling out all the forms and handing th...  Negative
# 14  From the moment I walked through the door, I w...  Positive
# 15  I had a total knee replacement.The treatment I...  Positive
# 16  I was admitted to hospital 29/06/2009 very ner...  Positive
# 17  the friendliness, caring attitude and professi...  Positive
# 18  The expert and professional treatment and afte...  Positive
# 19  Both my husband and Daughter have had the need...  Positive
# 20  I cannot praise and thank the staff enough for...  Positive
# 21  My son was treated on NHS at Abbey Gisburne Pa...  Positive
# 22  the food was lovely,my consultant is a nice gu...  Positive
# 23  The hospital is in a fantastic location, with ...  Positive
# 24  from my initial appointments up to my surgery ...  Positive
# 25  Individual rooms with en suite bathroom, direc...  Positive
# 26  I had a back  operation and spent 1 night ther...  Positive
# 27  Exceptional care. I needed pain killers after ...  Positive
# 28  I was given first class care whilst an inpatie...  Positive
# 29  Nothing. My father was neglected most of the t...  Positive
# 30  My father was dying and the hospital staff wer...  Positive
# 31  I attended the minor injuries unit and althoug...  Positive
# 32               The staff were friendly and helpful.  Positive
# 33  The minor injuries staff are lovely and helpfu...  Positive
# 34  The nurse who dealt with me was very caring an...  Positive
# 35  i was x.rayedwithin 10 mins in and out very ef...  Positive
# 36  The reception staff were exceptionally helpful...  Positive
# 37  the whole aspect once i got in the hospital wa...  Positive
# 38  My father who has lived in Accrington for over...  Positive
# 39  I liked it because the health professional tha...  Positive
# 40  Modern unit, comfortable waiting room chairs, ...  Positive
# 41  The care and professionalism shown by all staf...  Positive
# 42  My 2 year old son had to go in for a general a...  Positive
# 43  The staff in all departments that I went to we...  Positive
# 44  I liked the friendly staff, not just the nurse...  Positive
# 45  I am a Patient at Addenbrookes Dialysis Unit. ...  Positive
# 46  I had a serious mototorcycle accident and cons...  Positive
# 47  The surgeon had an excellent manner which put ...  Positive
# 48  Since the building of the New Addenbrookes Hos...  Negative
# 49  My mother-in-law was admitted to Addenbrooke's...  Positive

# %%
df.sentiment.value_counts()
# Out:
# Positive    12275
# Negative     1146
# Neutral         4
# Name: sentiment, dtype: int64

# %%
df = df[df.sentiment != "I can't tell"]

# %%
X = df['comment']
y = df['sentiment']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = .2)

# %%
print("Training set size:", len(X_train))
print("Validation set size:", len(X_val))
print("Test set size:", len(X_test))
# Out:
# Training set size: 8812
# Validation set size: 2204
# Test set size: 2755

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
def ascii_only(text):
    return text.encode("ascii", "ignore").decode()

# %%
def make_lower(text):
    return text.lower()

# %%
# Find links and remove them

def remove_links(text):
    p = '((http\w*:\/\/)?(www\.\w+)?(\w+\.(com|co|ly|ch|org|net)+)(\/\w+)?)'
    return re.sub(p, ' ', text)

# %%
# Remove html symbol
def remove_html(text):
    return re.sub("[^A-Za-z0-9 ]\w+", ' ', text)

# %%
# Remove mentions
def remove_mentions(text):
    return re.sub("(@\w*)", ' ', text)

# %%
# Remove unnecessary punctuations
import string
punctuations = string.punctuation
punctuations = punctuations + '�' + string.digits

def remove_punctuations(text, punctuations):
    table_ = str.maketrans('', '', punctuations)
    return text.translate(table_)

# %%
def remove_brandwords(text):
    p = '''#?(iphone|ipad|sxsw|hcsm|google|apple|cisco|austin|
    atari|intel|mac|pc|blackberry|android|linux|ubuntu)[a-z0-9]*'''
    return re.sub(p, ' ', text)

# %%
import nltk
nltk.download('stopwords')

from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

sw = (stopwords.words('english'))

def lemmatize(x, sw):
    wnl = WordNetLemmatizer()
    return ' '.join([wnl.lemmatize(w) for w in x.split() if w not in sw])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def preprocessing(df, punctuations, stopwords):
    df['comment'] = df.comment.apply(lambda x: ascii_only(x))
    df['comment'] = df.comment.apply(lambda x: make_lower(x))
    df['comment'] = df.comment.apply(lambda x: remove_links(x))
    df['comment'] = df.comment.apply(lambda x: remove_html(x))
    df['comment'] = df.comment.apply(lambda x: remove_mentions(x))
    df['comment'] = df.comment.apply(lambda x: remove_punctuations(x, punctuations))
    df['comment'] = df.comment.apply(lambda x: remove_brandwords(x))
    df['comment'] = df.comment.apply(lambda x: lemmatize(x, sw))
    
    return df

# %%
df['comment'] = df['comment'].astype(str)

# %%
import nltk
nltk.download('wordnet')
dataset = preprocessing(pd.DataFrame(df), punctuations, sw)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
